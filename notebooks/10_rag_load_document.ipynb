# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# TEXT Documents Loader

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/spoken.txt")
texts=loader.load()
len(texts)

oneDoc=texts[0]
print(oneDoc.page_content)
# Out:
# 1

# %% [markdown]
# PDF Documents Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("../data/trading.pdf")
docs=loader.load()
len(docs)

# %%
oneDoc=docs[0]
print(oneDoc.page_content)

# %% [markdown]
# CSV File loader

# %%
from langchain_community.document_loaders import CSVLoader
loader=CSVLoader("../data/employees.csv")
docs=loader.load()
len(docs)
docs[:10]

# %% [markdown]
# Web page loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_path="https://github.com/mdrashid93/GENAI")
docs=loader.load()
docs[0].page_content
# docs[0].metadata

# %% [markdown]
# wikipedia loader

# %%
from langchain_community.document_loaders import WikipediaLoader
laoder=WikipediaLoader(query="GEN AI",load_max_docs=2)
docs=laoder.load()
docs[0].page_content
