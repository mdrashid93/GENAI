# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm=ChatOpenAI(model="gpt-4o")

# %%
prompts=[
    {"role":"system","content":"you are a javascripts devloper ?"},
    {"role":"user","content":"diffrence b/w map and filter ?"}
]
res=llm.invoke(prompts)
print(res.content)

# %% [markdown]
# #### prompt templates dynamic prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm=ChatOpenAI(model="gpt-4o")
out=StrOutputParser()

# %%
#### my self chain node
def transform_case(result:str):
    return result.upper()

# %%
# prompts=([
#     {"role":"system","content":"you are a translator and input {language}"},
#     {"role":"user","content":"{query}"},
# ])

# %%
# final_prompts=prompts.format_messages(language="hindi",
#                                       query=" l love you python and kingkobra")
# res=llm.invoke(final_prompts)
# print(res.content)

# %%
# res=llm.invoke(prompts.invoke({"language":"hindi","query":"i love you "}))
# res.content

# %% [markdown]
# chains

# %%
chains=prompts | llm | out | transform_case

# %%
res=chains.invoke({"language":"hinglish","query":"i love langchain ?"})
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 res=chains.invoke({"language":"hinglish","query":"i love langchain ?"})
#       2 print(res)
#
# NameError: name 'chains' is not defined
