# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("what is the current value of dollar")

# %%
print(res.content)

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")

# %%
res=llm.invoke("how to find largest number from a list in python?")

# %%
print(res.content)

# %% [markdown]
# ####static prompts

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gemini-2.5-flash")

# %%
prompts=[
    
    ("system","you are a python developer."), ### (type,)"system","ai",,"user"
    ("user","how to sort the array.")
]

# %%
res=llm.invoke(prompts)
print(res.content)
